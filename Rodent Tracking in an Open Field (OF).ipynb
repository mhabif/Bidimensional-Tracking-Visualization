# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
from matplotlib.colors import Normalize
from matplotlib import cm
#%matplotlib inline

# %%
#Import data-sets
data_F_wt_J65R2 = pd.read_csv (r'F_wt_J65R2.txt')
data_F_wt_ffyb1 = pd.read_csv (r'F_wt_ffyb1_2de3.txt')
data_M_wt_J18R1_21 = pd.read_csv (r'M_wt_J18R1_21.txt')

# %%
# FEMALE WT

plt.subplots(figsize=(10, 6.6))

plt.style.use('seaborn-white') # see https://python-graph-gallery.com/199-matplotlib-style-sheets/

plt.subplot(231)
plt.plot(data_M_wt_J18R1_21.x, data_M_wt_J18R1_21.y, color='red', linestyle='-', linewidth=1)
plt.xlabel('data_M_wt_J18R1_21', fontsize=16, fontweight='bold')
plt.xticks([])
plt.yticks([])

plt.subplot(232)
plt.plot(data_F_wt_ffyb1.x, data_F_wt_ffyb1.y, color='blue', linestyle='-', linewidth=1)
plt.xlabel('F_wt_ffyb1', fontsize=16, fontweight='bold')
plt.xticks([])
plt.yticks([])

# Data
x = data_F_wt_J65R2.x
y = data_F_wt_J65R2.y

data = np.vstack([x,y])
nbins = 100
k = stats.gaussian_kde(data)
xi, yi = np.mgrid[x.min():x.max():nbins*1j, y.min():y.max():nbins*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

plt.subplot(234)
plt.pcolormesh(xi, yi, zi.reshape(xi.shape), shading='gouraud', cmap=plt.cm.jet) #gist_yarg
#plt.contour(xi, yi, zi.reshape(xi.shape) )
plt.xlabel('F_wt_J65R2', fontsize=16, fontweight='bold')
plt.xticks([])
plt.yticks([])

# Data
x = data_M_wt_J18R1_21.x
y = data_M_wt_J18R1_21.y

data = np.vstack([x,y])
nbins = 100
k = stats.gaussian_kde(data)
xi, yi = np.mgrid[x.min():x.max():nbins*1j, y.min():y.max():nbins*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

plt.subplot(235)
plt.pcolormesh(xi, yi, zi.reshape(xi.shape), shading='gouraud', cmap=plt.cm.jet) #gist_yarg
#plt.contour(xi, yi, zi.reshape(xi.shape) )
plt.xlabel('data_M_wt_J18R1_21', fontsize=16, fontweight='bold')
plt.xticks([])
plt.yticks([])

plt.savefig("Old_wt_13mo_tracking.pdf", format="pdf")

plt.show()
